# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.ticker import NullFormatter
plt.rcParams['font.size'] = 13

# manifold.TSNE
from sklearn import manifold  #, datasets
from time import time

from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## Data and labels
# In this example we know the labels, hence we can test the performances of t-SNE and DBSCAN

# %%
fname,fnamey="x_12d.dat","y_12d.dat"
data=np.loadtxt("DATA/"+fname, delimiter='\t')
y=np.loadtxt("DATA/"+fnamey,dtype=int)
N=len(data)
D=len(data[0])
print("N=",N,"  L=D=",D)
x=data
# Out:
# N= 600   L=D= 12

# %% [markdown]
# ## Find the typical minimum distance between points
# This yields a typical scale, to be used as a reference for "eps"

# %%
nn = 10
nbrs = NearestNeighbors(n_neighbors=nn+1).fit(x) #, algorithm='ball_tree'
d, ind = nbrs.kneighbors(x) # returns indices of and distances to the neighbors of each point 
dd=d.T # riga 0 = [distanza del primo sample da neighbour 0 (sè stesso) , distanza del sample 2 da neighbour 0 (sè stesso), ..]
       # riga i = [distanza del primo sample da neighbour i, distanza del sample 2 da neighbour i]
# dd -- 11 righe, 600 colonne 

# note: dd[0] has a trivial set of zeros
listc= ["#0000DD","#8000FF","#FF00FF","#FF0080","#DD0000",
        "#FF8000","#E0E000","#30D000","#00A030","#33A0A0"]

# plot i represent distances from neighbor i 
for i in range(1,nn+1):
    plt.plot(np.sort(dd[i]),c=listc[i-1],label=str(i))
    plt.xlabel("rank")
    plt.ylabel("distance to i-th neighbor")
plt.legend(ncol=2)
plt.show()
mean_min_dist = np.mean(dd[1])
print("mean minimum distance between points: ",mean_min_dist)
# Out:
# mean minimum distance between points:  162.34622464324366

# %% [markdown]
# ## t-SNE visualization, for true labels

# %%
np.random.seed(0)
n_samples = N
n_components = 2 
perplexities = [2, 4, 8, 16, 32]
Np = len(perplexities)
mycmap = ListedColormap(["blue","red","gold" ])

(fig, subplots) = plt.subplots(1, Np , figsize=(3*Np, 2.7))

X_all = [None]
for i, perplexity in enumerate(perplexities):
    ax = subplots[i]

    t0 = time()
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(data)
    t1 = time()
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=y,cmap=mycmap)
    ax.tick_params(left=False,bottom=False)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    X_all.append(Y)
    
plt.show()

# %% [markdown]
# ## Different random initial states (random_state=i)

# %%
n_samples = N
n_components = 2 
mycmap = ListedColormap(["blue","red","gold" ])

(fig, subplots) = plt.subplots(1,Np , figsize=(3*Np, 2.7))

X_all = [None]

perplexity= 8

for i in range(5):
    np.random.seed(i) 
    ax = subplots[i]

    t0 = time()
    tsne = manifold.TSNE(n_components=n_components, 
                         init='random',random_state=i, 
                         perplexity=perplexity)
    Y = tsne.fit_transform(data)
    t1 = time()
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=y,cmap=mycmap)
    ax.tick_params(left=False,bottom=False)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')
    X_all.append(Y)
    
plt.show()

# %% [markdown]
# ## DBSCAN: find labels by applying clustering

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
cpalette = ["blue","red","gold","black","magenta","green","cyan","#1CE6FF", "#FF34FF", "#FF4A46","#008941", "#006FA6", "#A30059", "#0000A6", "#63FFAC","#B79762", "#004D43", "#8FB0FF", "#997D87","#5A0007", "#809693","#1B4400", "#4FC601", "#3B5DFF", "#4A3B53","#886F4C","#34362D", "#B4A8BD", "#00A6AA", "#452C2C","#636375", "#A3C8C9", "#FF913F", "#938A81","#575329", "#00FECF", "#B05B6F"]
from collections import OrderedDict
ms = 6

def clustering(y):
    # Finds position of labels and returns a dictionary of cluster labels to data indices.
    yu = np.sort(np.unique(y))
    clustering = OrderedDict()
    for ye in yu:
        clustering[ye] = np.where(y == ye)[0]
    return clustering

def entropy(c, n_sample):
    # Measures the entropy of a cluster
    h = 0.
    for kc in c.keys():
        p=len(c[kc])/n_sample
        h+=p*np.log(p)
    h*=-1.
    return h

# Normalized mutual information function
# Note that this deals with the label permutation problem
def NMI(y_true, y_pred):
    """ Computes normalized mutual information: where y_true and y_pred are both clustering assignments
    """
    w = clustering(y_true)
    c = clustering(y_pred)
    n_sample = len(y_true)

    Iwc = 0.
    for kw in w.keys():
        for kc in c.keys():
            w_intersect_c=len(set(w[kw]).intersection(set(c[kc])))
            if w_intersect_c > 0:
                Iwc += w_intersect_c*np.log(n_sample*w_intersect_c/(len(w[kw])*len(c[kc])))
    Iwc/=n_sample
    Hc = entropy(c,n_sample)
    Hw = entropy(w,n_sample)

    return 2*Iwc/(Hc+Hw)

def plotting_ax(X, y, ax):
    # plotting function
    for i, yu in enumerate(np.unique(y)):
        pos = (y == yu)
        ax.scatter(X[pos,0], X[pos,1],c=cpalette[i%len(cpalette)],s=ms)

# DBSCAN has a few parameters, let's sweep over a few parameters and see what happens
np.random.seed(12345)
n_true_center=3
#X, ytrue = make_blobs(10000, 2, n_true_center) # Generating random gaussian mixture
X2D = X_all[2] # best(?) visualization above
X = data
y_true = y

#eps_range = [0.01,0.1,0.5,1.0,10.]
if mean_min_dist<10:
    r=mean_min_dist
else:
    r = int(mean_min_dist)
    
eps_range = [r/2,r,1.5*r,2*r]

min_sample_range = [2,3,5,10]
DIMY=len(eps_range)
DIMX=len(min_sample_range)
fig, ax = plt.subplots(DIMY+1,DIMX,figsize=(15,18))

i,j=0,0
nmi=1
plotting_ax(X2D,y,ax[i,j])
ax[i,j].set_title('True labels')
for j in range(1,DIMX): fig.delaxes(ax[i,j])
    
for i, eps in enumerate(eps_range):
    for j, min_samples in enumerate(min_sample_range):
        model = DBSCAN(eps=eps, min_samples=min_samples)
        model.fit(X)
        y_hat = model.labels_
        plotting_ax(X2D,y_hat,ax[i+1,j])
        nmi=NMI(y_hat, y_true)
        ax[i+1,j].set_title(r'$\epsilon$=%.0f, $m_P$=%i, NMI=%.3f'%(eps,min_samples,nmi))

plt.tight_layout(h_pad=0.5)
plt.show()

# %% [markdown]
# We decide to further analize the results obtained with certain pairs of values for $\epsilon$ and $m_p$. For each value of $m_p$ we look at the plot showing the distance to the $m_p$-th neighbour and select as $\epsilon$ both the mean distance and the value for which the plot exhibits an elbow.

# %%
mean_dist = np.mean(dd, axis=1)
r = [int(d) for d in mean_dist]

min_sample_range = [2, 3, 5, 7]

eps_1 = [r[i] for i in min_sample_range] # mean distance for each mp
eps_2 = [240, 250, 255, 260] # elbow of the plot for each mp
eps = eps_1 + eps_2

fig, ax = plt.subplots(2, DIMX, figsize=(15, 7))

for i, (min_samples, eps) in enumerate(zip(min_sample_range * 2, eps)):
    model = DBSCAN(eps=eps, min_samples=min_samples)
    model.fit(X)
    y_hat = model.labels_
    
    row = i // DIMX
    col = i % DIMX
    
    plotting_ax(X2D, y_hat, ax[row,col])
    nmi = NMI(y_hat, y_true)
    ax[row,col].set_title(r'$\epsilon$=%.0f, $m_P$=%i, NMI=%.3f' % (eps, min_samples, nmi))

plt.tight_layout(h_pad=0.5)
plt.show()

# %% [markdown]
# We now plot a heat-map showing the normalized mutual information (NMI) between true and predicted clusters:

# %%
y_true = y #true labels

#function used in imshow
def z(min_samples,eps):
    model = DBSCAN(eps=eps, min_samples=min_samples)
    model.fit(X)
    y_hat=model.labels_ #predicted labels
    return NMI(y_true, y_hat)  

#generating the grid
EPS = np.linspace(1,300)
MP = np.arange(1,50)
m_mesh, e_mesh = np.meshgrid(MP, EPS)

Z = np.vectorize(z)(m_mesh, e_mesh)

# %%
from matplotlib.ticker import AutoMinorLocator

plt.figure(figsize=(6,5))  # Adjust the size as needed
plt.imshow(Z, vmin = Z.min(), vmax = Z.max(), 
                 extent =[m_mesh.min(), m_mesh.max(), e_mesh.max(), e_mesh.min()], aspect='auto')
plt.colorbar()  # Add color bar
plt.tight_layout()
plt.xlabel('$m_p$')
plt.ylabel('$\epsilon$')
plt.title('NMI for DBSCAN')
plt.gca().xaxis.set_minor_locator(AutoMinorLocator())
plt.gca().yaxis.set_minor_locator(AutoMinorLocator())
plt.show()

# %%
max_idx = np.unravel_index(np.argmax(Z), Z.shape)  # Combined index for max value
min_samples, eps = MP[max_idx[1]],EPS[max_idx[0]]

model = DBSCAN(eps=eps, min_samples=min_samples)
model.fit(X)
y_hat = model.labels_
fig, ax = plt.subplots()
plotting_ax(X2D, y_hat, ax)
plt.title(f'Best DBSCAN (NMI={Z.max():.2f}, $\epsilon$={int(eps)}, $m_p$={min_samples})')
plt.show()

# %% [markdown]
# The values for which NMI is maximized seem to be the ones we selected in the cells above. The best result is obtained by imposing $\epsilon$ =
# 257 and $m_p$= 1.
#
# The high NMI region indicates a positive correlation between $\epsilon$ and $m_p$. A positive outcome implies a correspondence between an increase in $\epsilon$ and $m_p$ as we're working with well defined clusters with roughly constant density.

# %%
from sklearn.decomposition import PCA

pca=PCA(n_components=3)
pca.fit(data)
transf_data=pca.transform(data)


fig,ax=plt.subplots(2,3,figsize=(20,10))
ax[0,0].scatter(transf_data[:,0],transf_data[:,1],c=y,cmap=mycmap)
ax[0,0].set_xlabel('First principal component')
ax[0,0].set_ylabel('Second principal component')

ax[0,1].scatter(transf_data[:,0],transf_data[:,2],c=y,cmap=mycmap)
ax[0,1].set_xlabel('First principal component')
ax[0,1].set_ylabel('Third principal component')

ax[0,2].scatter(transf_data[:,1],transf_data[:,2],c=y,cmap=mycmap)
ax[0,2].set_xlabel('Second principal component')
ax[0,2].set_ylabel('Third principal component')

ax[1,0].scatter(transf_data[:,0],transf_data[:,1],c=y_hat,cmap=mycmap)
ax[1,0].set_xlabel('First principal component')
ax[1,0].set_ylabel('Second principal component')

ax[1,1].scatter(transf_data[:,0],transf_data[:,2],c=y_hat,cmap=mycmap)
ax[1,1].set_xlabel('First principal component')
ax[1,1].set_ylabel('Third principal component')

ax[1,2].scatter(transf_data[:,1],transf_data[:,2],c=y_hat,cmap=mycmap)
ax[1,2].set_xlabel('Second principal component')
ax[1,2].set_ylabel('Third principal component')

ax[0, 1].set_title('Row 1: PCA with true labels')
ax[1, 1].set_title('Row 2: PCA with best DBSCAN predicted labels')

plt.tight_layout(pad=0.5)
plt.tight_layout(h_pad=0.5)

# %%
from mpl_toolkits.mplot3d import Axes3D

pca=PCA(n_components=12) 
pca.fit(data)

fig = plt.figure(figsize=(12,15))
ax = fig.add_subplot(121, projection='3d')
ax.scatter(transf_data[:,0],transf_data[:,1],transf_data[:,2],c=y,cmap=mycmap)
ax.set_xlabel('$1^{st}$ principal component', fontsize=8)
ax.set_ylabel('$2^{nd}$ principal component', fontsize=8)
ax.set_zlabel('$3^{rd}$ principal component', fontsize=8) 
ax.tick_params(axis='both', labelsize=8)
ax.set_title('$1^{st}$, $2^{nd}$ and $3^{rd}$ principal components')
ax.set_aspect('equal')


ax1 = fig.add_subplot(122, projection='3d')
ax1.scatter(transf_data[:,1],transf_data[:,2],transf_data[:,3],c=y,cmap=mycmap)
ax1.set_xlabel('$2^{nd}$ principal component', fontsize=8)
ax1.set_ylabel('$3^{rd}$ principal component', fontsize=8)
ax1.set_zlabel('$4^{th}$ principal component', fontsize=8)
ax1.tick_params(axis='both', labelsize=8)
ax1.set_title('$2^{nd}$, $3^{rd}$ and $4^{th}$ principal components')
ax1.set_aspect('equal')

plt.show()

transf_data=pca.transform(data)
print('Total percentage of variance explained:', pca.explained_variance_ratio_)
# Out:
# Total percentage of variance explained: [0.5608603  0.309137   0.0928226  0.00510008 0.00485139 0.00444663
#  0.00432263 0.00418779 0.00392144 0.00365984 0.00348747 0.00320282]

# %% [markdown]
# We see that ~96% of the total variance is in three components and the ~87% in two. The third component has a variance of ~9%, but it has a defined enough structure so that we can clearly distinguish three shapes. We assume the other components to be random noise given the variance ratio and the 3D plots.
#
# By looking at the 3d PCA visualization it is clear why DBSCAN identifies at best two clusters out of three and that is because the yellow shape almost intersects the red one so they are grouped together while the blue shape never intersects any other cluster.
